# %%
import pandas as pd

# %%
df = pd.read_csv('TSP_results/results.csv', index_col=0, skiprows=[11,16,19,20,21,22,23,24,26,27,28,30,40,41,42])

# %%
df_2 = df.loc[:,['NN_cost','NN2Opt_cost', 'NN2OptDLB_cost', 'NN3Opt_cost','NN3OptDLB_cost','repNN_cost','repNN2Opt_cost','repNN2OptDLB_cost','repNN3Opt_cost','repNN3OptDLB_cost']]

# %%
df['opt_result'].iloc[0]
# Out:
# 44303

# %%
costs = df.values
costs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/michele/Documents/TSP-local-search/plot.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/home/michele/Documents/TSP-local-search/plot.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> costs = df.values()
#       <a href='vscode-notebook-cell:/home/michele/Documents/TSP-local-search/plot.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> costs
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
for i, row in enumerate(costs):
    for j in range(len(row)):
        print(costs[i][j])
# Out:
# pr107.tsp
# 46678.15415698668
# 0.0013751983642578
# 44610.9152930388
# 0.0618050098419189
# 44610.9152930388
# 0.0066373348236083
# 44610.9152930388
# 18.37687969207764
# 44610.9152930388
# 2.985891103744507
# 46678.15415698668
# 0.6746973991394043
# 44610.9152930388
# 0.7195086479187012
# 44610.9152930388
# 0.6800179481506348
# 44610.9152930388
# 9.374794006347656
# 44610.9152930388
# 3.689992666244507
# 44303
# pr124.tsp
# 69299.42521616323
# 0.0019376277923583
# 60304.03449516656
# 0.0670990943908691
# 60413.14498485148
# 0.0093002319335937
# 60304.03449516656
# 29.938613176345825
# 60304.03449516656
# 4.641245603561401
# 67056.60067424613
# 1.0417234897613523
# 60665.3489228791
# 1.233130931854248
# 63313.576515579
# 1.076056718826294
# 60133.73204683443
# 22.648021936416622
# 60133.73204683443
# 5.982324123382568
# 59030
# kroC100.tsp
# 26327.36210986593
# 0.001373291015625
# 22130.7422530985
# 0.0665507316589355
# 22663.61389244914
# 0.00642991065979
# 21516.98790970977
# ...
